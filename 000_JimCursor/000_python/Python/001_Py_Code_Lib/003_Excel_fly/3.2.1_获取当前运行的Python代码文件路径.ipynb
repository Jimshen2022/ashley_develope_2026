# %%
import os

from distributed.diagnostics.progress_stream import counts

path = os.getcwd()
print(path)
# Out:
# D:\GitHub\Python2038\001_Py_Code_Lib\003_Excel_fly

# %%
import os
path = r'C:\Users\jishen\Downloads'
file_list = os.listdir(path)
print(file_list)
count = 0
for i in range(len(file_list)):
    count += 1
print(count)
# Out:
# ['001.jpg', '001PNG.PNG', '001_MIL AMFLIBL.ITMRVA_20250111_105021.xlsx', '002.jpg', '002PNG.PNG', '003.jpg', '00640 Transactions.xlsb', '0093193.xlsx', '01a SPW-P1-LO-230220 (PH1 Enlarged) (1).pdf', '02-01-2025 - CA NGAY 1.xlsb', '1.xlsx', '10-6.xlsx', '10.xlsx', '1020246.xlsb', '1020246.xlsx', '110pcs damaged  lack materials pieces.xlsx', '1150271.xlsx', '12.16.xlsx', '12.xlsx', '1223972 - Hot Loading Import - Include customer information in HighJump - Development.xlsx', '13.xlsx', '151.xlsx', '1790212.xlsx', '1964077.xlsx', '2.xlsx', '2024.12.23 Wanek and DC WH_Staffing Report.xlsb', '20240927.jpg', '20241103.xlsx', '20648.xlsx', '2110477.xlsx', '22140.xlsx', '2410126303.pdf', '2740338.xlsx', '2CB (1).pdf', '2CD (1).pdf', '2G5P25.xlsx', '3.xlsx', '30223-2.xlsx', '30223.xlsx', '3140338.xlsx', '335 C-CNW & DR.pbix', '347 (1).xlsx', '347 (2).xlsx', '347.xlsx', '374.xlsx', '3810488.xlsx', '3CB (1).pdf', '3CB (2).pdf', '4.xlsx', '4070912.xlsx', '43745.xlsx', '4CB (1).pdf', '5.xlsx', '50
# ...
